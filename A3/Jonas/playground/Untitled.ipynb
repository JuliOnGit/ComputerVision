# %%
import numpy as np
import cv2
import os
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
f = open("../../data/testPairs", "r")
for x in f:
    pair = x.split()
    img1 = cv2.imread("../../data/test/{}".format(pair[0]), 1)
    #plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
    #plt.show()
    img2 = cv2.imread("../../data/test/{}".format(pair[1]), 1)
    #plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
    #plt.show()
f.close()

# %%
f = open("../../data/testPairs", "r")
x = f.readline()
x = f.readline()
pair = x.split()
img1 = cv2.imread("../../data/test/{}".format(pair[0]), 1)
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.show()
print(pair[0])
img2 = cv2.imread("../../data/test/{}".format(pair[1]), 1)
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.show()
print(pair[1])
f.close()
# Out:
# kyOKETaEuXoS.jpg
# h5TCrc6bqYUI.jpg
